# %% [markdown]
# ### Quantitative vs. Quantitative
#     1. Scatterplot
#     2. Line plot

# %% [markdown]
# ### Categorical vs. Quantitative
#     1. Bar chart (on summary statistics)
#     2. Grouped kernel density plots
#     3. Box plots
#     4. Violin plots

# %% [markdown]
# ### Categorical vs. Categorical
#     1. Stacked bar chart
#     2. Grouped bar chart
#     3. Segmented bar chart

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101">
#     <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#b53f05"> (Titanic Data Set)

# %% [markdown]
# ### Problem Feature:
# The sinking of the Titanic is one of the most infamous shipwrecks in history. **On April 15, 1912**, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing **1502 out of 2224** passengers and crew. That's why the name DieTanic. This is a very unforgetable disaster that no one in the world can forget.
#
# 1.  **Age** ==>> Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# 2. **Sibsp** ==>> The dataset defines family relations in this way...
#
#     a. Sibling = brother, sister, stepbrother, stepsister
#
#     b. Spouse = husband, wife (mistresses and fiancés were ignored)
#
# 3. **Parch** ==>> The dataset defines family relations in this way...
#
#     a. Parent = mother, father
#
#     b. Child = daughter, son, stepdaughter, stepson
#
#     c. Some children travelled only with a nanny, therefore parch=0 for them.
#
# 4. **Pclass** ==>> A proxy for socio-economic status (SES)
#
#     * 1st = Upper
#     * 2nd = Middle
#     * 3rd = Lower
#
# 5. **Embarked** ==>> nominal datatype
# 6. **Name** ==>> nominal datatype . It could be used in feature engineering to derive the gender from title
# 7. **Sex** ==>>  nominal datatype
# 8. **Ticket** ==>> that have no impact on the outcome variable. Thus, they will be excluded from analysis
# 9. **Cabin** ==>>  is a nominal datatype that can be used in feature engineering
# 11. **Fare** ==>>  Indicating the fare
# 12. **PassengerID ** ==>> have no impact on the outcome variable. Thus, it will be excluded from analysis
# 11. **Survival** is ==>> **[dependent variable], 0 or 1

# %%
df["Survived"] = df["Survived"].astype(int).astype(str)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> Loading the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> import the dataset

# %%
df = pd.read_csv('Titanictrain.csv')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> size of the data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Statistical characteristics of the data

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> Age columns

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Column names

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Numerical Features,Categorical Features, Alphanumeric Features

# %% [markdown]
#     * Categorical: Survived, Sex, and Embarked. Ordinal: Pclass.
#     * Numerical Features: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)
#     * Alphanumeric Features: Ticket, Cabin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Categorical vs. Quantitative

# %% [markdown]
#     * Categorical: Survived, Sex, and Embarked. Ordinal: Pclass.
#     * Numerical Features: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> Bar plot for showing Sex Vs Survived.

# %%
df[df.Survived==1]['Sex'].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df[df.Survived==0]['Sex'].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
#draw a bar plot of survival by sex
df[df.Survived==1]['Sex'].value_counts().plot(kind = 'bar')
plt.show()

#print percentages of females vs. males that survive
df.Sex.value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
data = df.copy()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %% [raw]
# 1. This bar plot above shows the distribution of female and male survived. The x_label represents Sex feature while the y_label represents the No.of passenger survived.
#
# 2. This bar plot shows that ~65% female passenger survived while only ~35% male passenger survived.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">Bar plot Pclass Vs Survived.And Observation

# %%
# Create subplot

# sns.barplot(x = "Pclass", y = "Survived", data=data, linewidth=2)
#print percentages of 1st vs. 2nd and 3rd class
df[df.Survived==1]['Pclass'].value_counts().plot(kind = 'bar')
plt.xlabel('Pclass')
plt.ylabel('No of survivors')
plt.show()
df[df.Survived==1]['Pclass'].value_counts(normalize = True)
# Out:
# 1    0.397661
# 3    0.347953
# 2    0.254386
# Name: Pclass, dtype: float64

# %%
pd.crosstab(index = df['Survived'],columns = df['Pclass']).plot(kind = 'bar',stacked = True)

# %%
pd.crosstab(index = df['Survived'],columns = df['Pclass']).plot(kind = 'bar')

# %%
136/(136+80)*100
# Out:
# 62.96296296296296

# %%
87/(87+97)*100
# Out:
# 47.28260869565217

# %%
119/(119+372)*100
# Out:
# 24.236252545824847

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %% [raw]
# 1. 62% first class passenger survived titanic tragedy, while
# 2. 47% second class and
# 3. 24% third class passenger survived.
#
# The rich people would mostly be staying in the upper decks of the ship, which would have been easier for evacuation.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> Bar plot for checking the both Survived vs Sex and Sex:Survived or Not.

# %%
#create a subplot

# create bar plot using groupby
pd.crosstab(index = df['Survived'],columns = df['Sex']).plot(kind = 'bar',stacked=True)
# create count plot
plt.title('Survived vs Sex')
plt.show()
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
pd.crosstab(index = df['Survived'],columns = df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
109/(577)*100
# Out:
# 18.890814558058924

# %%
233/(314)*100
# Out:
# 74.20382165605095

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">  Observation:

# %%
1. No of Male is 577 > female(314)
2. More females have survived compared to males
3. 18.8% of males have only survived where as 74.2% of females have survived

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Violinplot plot for checking
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    a) Pclass vs. Age sliced by Survived
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    b) Sex vs Age sliced by Survived.

# %%
# create subplot plot

f,ax=plt.subplots(1,2,figsize=(18,8))

# create violinplot plot using groupby

sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [raw]
# 1.Pclass 1 has more adults and elders than childern(age<18),
#     where as Pclass 2 and 3 have more children in it.
#
# 2.Survival chances for Passenegers aged 20-50 from Pclass1 is high.
# 3.For males, the survival chances decreases with an increase in age.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">Bar(count) plot for checking the Embarked vs (No. of passengers, sex, Survived , Pclass). And your Observations

# %%
# create subplot plot
f,ax=plt.subplots(2,2,figsize=(20,10))

# create Bar (count) plot for Embarked vs. No. Of Passengers Boarded
sns.countplot(x='Embarked',data = df,ax=ax[0,0],color = 'skyblue')
ax[0,0].set_title('No. Of Passengers Boarded for Embarked')

# create Bar (count) plot for Embarked vs. Male-Female Split
sns.countplot(x = 'Embarked',data = df,hue = 'Sex',ax = ax[0,1], color = 'g')
ax[0,1].set_title('Male Female Split for Embarked')

# create Bar (count) plot for Embarked vs Survived
sns.countplot(x = 'Embarked',data = df,hue = 'Survived',ax = ax[1,0], color = 'teal')
ax[1,0].set_title('Survived vs non Survived for Embarked')

# create Bar (count) plot for Embarked vs Pclass
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1],color = 'darkblue')
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [raw]
# 1. Maximum passenegers boarded from S. Majority of them being from Pclass3.
#
# 2. Port Q had almost 95% of the passengers were from Pclass3.
#
# 3. No of males from S port are double of female
#
# 4. 2/3rd of passengers from S port have not surived

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">Box plot for pclass vs Age. And Observations

# %%
ax= sns.boxplot(x="Pclass", y="Age", data=data,color = 'crimson')
ax= sns.swarmplot(x="Pclass", y="Age", data=data,color="lightpink")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [raw]
# 1. Average age goes down from class 1 to class 3.
# 2. We can also see Outliers in all classes

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Quantitative vs. Quantitative

# %% [raw]
#     Numerical Features: Age (Continuous), Fare (Continuous)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">Scatter plot for showing age & fare with target varialble.

# %%
sns.lmplot(x = 'Age',y='Fare',data= df,hue = 'Survived',fit_reg=False)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %% [raw]
#  Not showing any significant relationships

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Frequency tables

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> Frequency tables (crosstabs)

# %%
one=pd.crosstab(index = df['Survived'],columns = 'count')
print(one)
# Out:
# col_0     count
# Survived
# 0           549
# 1           342

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> Two-way-table for survival vs sex

# %%
two=pd.crosstab(index = df['Survived'],columns = df['Sex'])
print(two)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> Parch column

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
sns.countplot('Parch',data=df)

# %%
pd.crosstab(index = df['Parch'],columns = df['Survived']).plot(kind = 'bar',stacked = True)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">Correlation plot using Headtmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %%
NO significant dependancy between the features

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:##e08484"> THE END
